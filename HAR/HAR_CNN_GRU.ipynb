# %%
import numpy as np
import pandas as pd
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Dense, Flatten, Dropout,
    Conv1D, MaxPooling1D, BatchNormalization,
    GRU
)
from tensorflow.keras.callbacks import (
    EarlyStopping, ReduceLROnPlateau
)
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import warnings

# pandas 경고 무시
warnings.filterwarnings('ignore', category=FutureWarning)

# ### Cell 1: 데이터 로드 및 전처리 (Standardization 추가) ###

def load_file(filepath):
    dataframe = pd.read_csv(filepath, header=None, sep='\s+')
    return dataframe.values

def load_group(filenames, prefix=''):
    loaded = list()
    for name in filenames:
        data = load_file(prefix + name)
        loaded.append(data)
    loaded = np.dstack(loaded)
    return loaded

def load_dataset_group(group, prefix=''):
    filepath = prefix + group + '/Inertial Signals/'
    filenames = list()
    filenames += ['total_acc_x_'+group+'.txt', 'total_acc_y_'+group+'.txt', 'total_acc_z_'+group+'.txt']
    filenames += ['body_acc_x_'+group+'.txt', 'body_acc_y_'+group+'.txt', 'body_acc_z_'+group+'.txt']
    filenames += ['body_gyro_x_'+group+'.txt', 'body_gyro_y_'+group+'.txt', 'body_gyro_z_'+group+'.txt']
    X = load_group(filenames, filepath)
    y = load_file(prefix + group + '/y_'+group+'.txt')
    return X, y

def load_dataset(prefix=''):
    # Google Drive 경로
    trainX, trainy = load_dataset_group('train', prefix + '/content/drive/MyDrive/UCI HAR Dataset/')
    testX, testy = load_dataset_group('test', prefix + '/content/drive/MyDrive/UCI HAR Dataset/')

    trainy = trainy - 1
    testy = testy - 1

    trainy_one_hot = to_categorical(trainy)
    testy_one_hot = to_categorical(testy)

    print("--- 데이터 로드 완료 ---")
    return trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot

# --- 데이터 로드 실행 ---
trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot = load_dataset()

# --- 훈련/검증 데이터 순차 분리 (shuffle=False) ---
X_train, X_val, y_train_one_hot, y_val_one_hot, y_train, y_val = train_test_split(
    trainX, trainy_one_hot, trainy, test_size=0.2, random_state=100, shuffle=False
)
print("\n--- 훈련/검증 데이터 순차 분리 완료 (shuffle=False) ---")

# --- 데이터 표준화 (Standardization) ---
mu = X_train.mean(axis=(0,1), keepdims=True)
sigma = X_train.std(axis=(0,1), keepdims=True) + 1e-8
X_train = ((X_train - mu) / sigma).astype('float32')
X_val = ((X_val - mu) / sigma).astype('float32')
testX = ((testX - mu) / sigma).astype('float32')
print("\n--- 데이터 표준화 완료 (Train 통계 기준) ---")


# ### Cell 2: 변수 설정 ###
n_timesteps, n_features, n_outputs = X_train.shape[1], X_train.shape[2], y_train_one_hot.shape[1]
print(f"\n--- 변수 설정 완료 ---")
print(f"Timesteps: {n_timesteps}, Features: {n_features}, Outputs: {n_outputs}")


# ### Cell 3 (신규): CNN-GRU 하이브리드 모델 정의 ###
print("\n--- CNN-GRU 하이브리드 모델 정의 ---")

inputs = Input(shape=(n_timesteps, n_features))

# CNN 블록 1
x = Conv1D(filters=128, kernel_size=5, activation='relu', padding='same')(inputs)
x = BatchNormalization()(x)
x = MaxPooling1D(pool_size=2)(x)
x = Dropout(0.3)(x)

# CNN 블록 2
x = Conv1D(filters=64, kernel_size=3, activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling1D(pool_size=2)(x)
x = Dropout(0.3)(x)

# GRU 블록
# GRU는 파라미터가 적어 과적합에 더 강할 수 있습니다.
x = GRU(128, recurrent_dropout=0.2)(x) # recurrent_dropout으로 과적합 제어
x = Dropout(0.5)(x)

# Dense 레이어
x = Dense(128, activation='relu')(x)
x = Dropout(0.4)(x) # Dense 레이어 뒤 Dropout
outputs = Dense(n_outputs, activation='softmax')(x)

# 모델 생성 및 컴파일
cnn_gru_model = Model(inputs, outputs)
cnn_gru_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

cnn_gru_model.summary()


# ### Cell 4: 훈련 (EarlyStopping 기준 = val_accuracy) ###
print("\n--- 모델 훈련 시작 (CNN-GRU) ---")

# EarlyStopping 콜백 (val_accuracy 기준)
early_stopping_cb = EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=10,
    restore_best_weights=True
)

# 학습률 감소 (ReduceLROnPlateau) 콜백
reduce_lr_cb = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.00001)

# batch_size=32로 훈련
model_history = cnn_gru_model.fit(
    x=X_train, y=y_train_one_hot,
    epochs=50,
    batch_size=32,
    validation_data=(X_val, y_val_one_hot),
    callbacks=[early_stopping_cb, reduce_lr_cb],
    verbose=1
)
print("\n--- 모델 훈련 완료 ---")


# ### Cell 5: 훈련 및 검증 손실 시각화 ###
print("\n--- 훈련/검증 손실 시각화 ---")
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']
epochs_range = range(1, len(loss) + 1)
plt.figure(figsize=(10, 6))
plt.plot(epochs_range, loss, 'y', label='Training loss')
plt.plot(epochs_range, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss (CNN-GRU)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()


# ### Cell 6: 훈련 및 검증 정확도 시각화 ###
print("\n--- 훈련/검증 정확도 시각화 ---")
acc = model_history.history['accuracy']
val_acc = model_history.history['val_accuracy']
plt.figure(figsize=(10, 6))
plt.plot(epochs_range, acc, 'y', label='Training acc')
plt.plot(epochs_range, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy (CNN-GRU)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()


# ###  Cell 7: 모델 평가 ###
print("\n--- 최종 테스트 데이터 평가 시작 ---")
pred_probs = cnn_gru_model.predict(testX)
pred = np.argmax(pred_probs, axis=-1)

# Confusion Matrix 계산
cm = confusion_matrix(testy, pred)
print("\nConfusion Matrix:")
print(cm)

# Accuracy Score
acc_score = accuracy_score(testy, pred)
print(f"\nAccuracy Score: {acc_score:.4f} (목표: 93% 이상)")

# Classification Report
print("\nClassification Report:")
print(classification_report(testy, pred, digits=3))

# Confusion Matrix 시각화
print("\n--- 혼동 행렬(Confusion Matrix) 시각화 ---")
plt.figure(figsize=(10, 8))
# yticklabels 오타 수정
sns.heatmap(cm, annot=True, fmt='d', xticklabels=range(6), yticklabels=range(6), cmap='Blues')
plt.title(f'Confusion Matrix (Accuracy: {acc_score:.4f})')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

print("\n--- 모든 과정이 완료되었습니다. ---")
# Out:
# <>:25: SyntaxWarning: invalid escape sequence '\s'
# <>:25: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipython-input-2199487817.py:25: SyntaxWarning: invalid escape sequence '\s'
#   dataframe = pd.read_csv(filepath, header=None, sep='\s+')
# --- 데이터 로드 완료 ---
#
# --- 훈련/검증 데이터 순차 분리 완료 (shuffle=False) ---
#
# --- 데이터 표준화 완료 (Train 통계 기준) ---
#
# --- 변수 설정 완료 ---
# Timesteps: 128, Features: 9, Outputs: 6
#
# --- CNN-GRU 하이브리드 모델 정의 ---
# Model: "functional_133"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_13 (InputLayer)     │ (None, 128, 9)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_34 (Conv1D)              │ (None, 128, 128)       │         5,888 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_34          │ (None, 128, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_34 (MaxPooling1D) │ (None, 64, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_49 (Dropout)            │ (None, 64, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_35 (Conv1D)              │ (None, 64, 64)         │        24,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_35          │ (None, 64, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_35 (MaxPooling1D) │ (None, 32, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_50 (Dropout)            │ (None, 32, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru (GRU)                       │ (None, 128)            │        74,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_51 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_26 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_52 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_27 (Dense)                │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 123,078 (480.77 KB)
#  Trainable params: 122,694 (479.27 KB)
#  Non-trainable params: 384 (1.50 KB)
# --- 모델 훈련 시작 (CNN-GRU) ---
# Epoch 1/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 23s 106ms/step - accuracy: 0.6278 - loss: 0.8820 - val_accuracy: 0.8600 - val_loss: 0.3205 - learning_rate: 0.0010
# Epoch 2/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 18s 97ms/step - accuracy: 0.9285 - loss: 0.2053 - val_accuracy: 0.9273 - val_loss: 0.2288 - learning_rate: 0.0010
# Epoch 3/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 22s 105ms/step - accuracy: 0.9400 - loss: 0.1505 - val_accuracy: 0.9293 - val_loss: 0.1990 - learning_rate: 0.0010
# Epoch 4/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 18s 98ms/step - accuracy: 0.9486 - loss: 0.1256 - val_accuracy: 0.9347 - val_loss: 0.2394 - learning_rate: 0.0010
# Epoch 5/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 20s 108ms/step - accuracy: 0.9565 - loss: 0.1093 - val_accuracy: 0.9286 - val_loss: 0.2553 - learning_rate: 0.0010
# Epoch 6/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 19s 101ms/step - accuracy: 0.9445 - loss: 0.1311 - val_accuracy: 0.9368 - val_loss: 0.2562 - learning_rate: 0.0010
# Epoch 7/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 18s 99ms/step - accuracy: 0.9472 - loss: 0.1153 - val_accuracy: 0.9211 - val_loss: 0.3109 - learning_rate: 0.0010
# Epoch 8/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 19s 101ms/step - accuracy: 0.9547 - loss: 0.0954 - val_accuracy: 0.9130 - val_loss: 0.3557 - learning_rate: 0.0010
# Epoch 9/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 18s 98ms/step - accuracy: 0.9444 - loss: 0.1131 - val_accuracy: 0.9191 - val_loss: 0.2923 - learning_rate: 5.0000e-04
# Epoch 10/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 19s 106ms/step - accuracy: 0.9524 - loss: 0.1073 - val_accuracy: 0.9218 - val_loss: 0.3186 - learning_rate: 5.0000e-04
# Epoch 11/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 18s 99ms/step - accuracy: 0.9616 - loss: 0.0813 - val_accuracy: 0.9375 - val_loss: 0.3259 - learning_rate: 5.0000e-04
# Epoch 12/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 18s 100ms/step - accuracy: 0.9546 - loss: 0.0853 - val_accuracy: 0.9137 - val_loss: 0.3205 - learning_rate: 5.0000e-04
# Epoch 13/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 20s 99ms/step - accuracy: 0.9515 - loss: 0.1041 - val_accuracy: 0.9286 - val_loss: 0.3281 - learning_rate: 5.0000e-04
# Epoch 14/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 18s 98ms/step - accuracy: 0.9597 - loss: 0.0801 - val_accuracy: 0.9218 - val_loss: 0.3437 - learning_rate: 2.5000e-04
# Epoch 15/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 20s 98ms/step - accuracy: 0.9599 - loss: 0.0835 - val_accuracy: 0.9211 - val_loss: 0.3526 - learning_rate: 2.5000e-04
# Epoch 16/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 18s 100ms/step - accuracy: 0.9546 - loss: 0.0845 - val_accuracy: 0.9273 - val_loss: 0.3560 - learning_rate: 2.5000e-04
# Epoch 17/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 19s 101ms/step - accuracy: 0.9590 - loss: 0.0795 - val_accuracy: 0.9266 - val_loss: 0.3566 - learning_rate: 2.5000e-04
# Epoch 18/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 18s 98ms/step - accuracy: 0.9564 - loss: 0.0890 - val_accuracy: 0.9307 - val_loss: 0.3662 - learning_rate: 2.5000e-04
# Epoch 19/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 19s 105ms/step - accuracy: 0.9619 - loss: 0.0760 - val_accuracy: 0.9381 - val_loss: 0.3651 - learning_rate: 1.2500e-04
# Epoch 20/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 20s 100ms/step - accuracy: 0.9614 - loss: 0.0792 - val_accuracy: 0.9381 - val_loss: 0.3605 - learning_rate: 1.2500e-04
# Epoch 21/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 18s 100ms/step - accuracy: 0.9629 - loss: 0.0724 - val_accuracy: 0.9368 - val_loss: 0.3646 - learning_rate: 1.2500e-04
# Epoch 22/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 20s 97ms/step - accuracy: 0.9625 - loss: 0.0730 - val_accuracy: 0.9375 - val_loss: 0.3644 - learning_rate: 1.2500e-04
# Epoch 23/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 18s 100ms/step - accuracy: 0.9589 - loss: 0.0767 - val_accuracy: 0.9375 - val_loss: 0.3717 - learning_rate: 1.2500e-04
# Epoch 24/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 19s 105ms/step - accuracy: 0.9630 - loss: 0.0712 - val_accuracy: 0.9381 - val_loss: 0.3749 - learning_rate: 6.2500e-05
# Epoch 25/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 19s 98ms/step - accuracy: 0.9595 - loss: 0.0725 - val_accuracy: 0.9381 - val_loss: 0.3729 - learning_rate: 6.2500e-05
# Epoch 26/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 19s 105ms/step - accuracy: 0.9656 - loss: 0.0722 - val_accuracy: 0.9375 - val_loss: 0.3750 - learning_rate: 6.2500e-05
# Epoch 27/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 18s 99ms/step - accuracy: 0.9608 - loss: 0.0741 - val_accuracy: 0.9341 - val_loss: 0.3742 - learning_rate: 6.2500e-05
# Epoch 28/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 20s 107ms/step - accuracy: 0.9637 - loss: 0.0726 - val_accuracy: 0.9368 - val_loss: 0.3720 - learning_rate: 6.2500e-05
# Epoch 29/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 19s 101ms/step - accuracy: 0.9621 - loss: 0.0746 - val_accuracy: 0.9368 - val_loss: 0.3675 - learning_rate: 3.1250e-05
#
# --- 모델 훈련 완료 ---
#
# --- 훈련/검증 손실 시각화 ---
# --- 훈련/검증 정확도 시각화 ---
# --- 최종 테스트 데이터 평가 시작 ---
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step
#
# Confusion Matrix:
# [[496   0   0   0   0   0]
#  [  2 448  21   0   0   0]
#  [ 13   0 407   0   0   0]
#  [  0   2   0 417  71   1]
#  [  0   0   0  94 438   0]
#  [  0   0   0   0   0 537]]
#
# Accuracy Score: 0.9308 (목표: 93% 이상)
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0      0.971     1.000     0.985       496
#            1      0.996     0.951     0.973       471
#            2      0.951     0.969     0.960       420
#            3      0.816     0.849     0.832       491
#            4      0.861     0.823     0.841       532
#            5      0.998     1.000     0.999       537
#
#     accuracy                          0.931      2947
#    macro avg      0.932     0.932     0.932      2947
# weighted avg      0.931     0.931     0.931      2947
#
#
# --- 혼동 행렬(Confusion Matrix) 시각화 ---
# --- 모든 과정이 완료되었습니다. ---
