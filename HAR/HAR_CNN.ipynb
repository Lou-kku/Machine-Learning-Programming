# %%
import numpy as np
import pandas as pd
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import (
    Input, Dense, Flatten, Dropout,
    Conv1D, MaxPooling1D, BatchNormalization
)
from tensorflow.keras.callbacks import (
    EarlyStopping, ReduceLROnPlateau
)
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import warnings

# pandas 경고 무시
warnings.filterwarnings('ignore', category=FutureWarning)

# ### Cell 1: 데이터 로드 및 전처리 함수 정의 ###

def load_file(filepath):
    dataframe = pd.read_csv(filepath, header=None, sep='\s+')
    return dataframe.values

def load_group(filenames, prefix=''):
    loaded = list()
    for name in filenames:
        data = load_file(prefix + name)
        loaded.append(data)
    loaded = np.dstack(loaded)
    return loaded

def load_dataset_group(group, prefix=''):
    filepath = prefix + group + '/Inertial Signals/'
    filenames = list()
    filenames += ['total_acc_x_'+group+'.txt', 'total_acc_y_'+group+'.txt', 'total_acc_z_'+group+'.txt']
    filenames += ['body_acc_x_'+group+'.txt', 'body_acc_y_'+group+'.txt', 'body_acc_z_'+group+'.txt']
    filenames += ['body_gyro_x_'+group+'.txt', 'body_gyro_y_'+group+'.txt', 'body_gyro_z_'+group+'.txt']
    X = load_group(filenames, filepath)
    y = load_file(prefix + group + '/y_'+group+'.txt')
    return X, y

def load_dataset(prefix=''):
    trainX, trainy = load_dataset_group('train', prefix + '/content/drive/MyDrive/UCI HAR Dataset/')
    testX, testy = load_dataset_group('test', prefix + '/content/drive/MyDrive/UCI HAR Dataset/')

    trainy = trainy - 1
    testy = testy - 1

    trainy_one_hot = to_categorical(trainy)
    testy_one_hot = to_categorical(testy)

    print("--- 데이터 로드 완료 ---")
    print(f"Train/Test Shapes (X, y, y_one_hot):")
    print(f"Train: {trainX.shape}, {trainy.shape}, {trainy_one_hot.shape}")
    print(f"Test:  {testX.shape}, {testy.shape}, {testy_one_hot.shape}")
    return trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot

# --- 데이터 로드 실행 ---
trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot = load_dataset()

# Train/Validation 분리
X_train, X_val, y_train_one_hot, y_val_one_hot, y_train, y_val = train_test_split(
    trainX, trainy_one_hot, trainy, test_size=0.2, random_state=100, shuffle=False
)
print("\n--- 훈련/검증 데이터 순차 분리 완료 (shuffle=False) ---")


# ### Cell 2: 변수 설정 ###
n_timesteps, n_features, n_outputs = X_train.shape[1], X_train.shape[2], y_train_one_hot.shape[1]
print(f"\n--- 변수 설정 완료 ---")
print(f"Timesteps: {n_timesteps}, Features: {n_features}, Outputs: {n_outputs}")


# ### Cell 3: "Deeper v1"  ###
print("\n--- 1D CNN 모델(v1) 정의 (kernel=3, filters=64,128,128) ---")
deep_cnn_model_v1 = Sequential()
deep_cnn_model_v1.add(Input(shape=(n_timesteps, n_features)))

# 첫 번째 컨볼루션 블록
deep_cnn_model_v1.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
deep_cnn_model_v1.add(BatchNormalization())
deep_cnn_model_v1.add(MaxPooling1D(pool_size=2))
deep_cnn_model_v1.add(Dropout(0.25))

# 두 번째 컨볼루션 블록
deep_cnn_model_v1.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
deep_cnn_model_v1.add(BatchNormalization())
deep_cnn_model_v1.add(MaxPooling1D(pool_size=2))
deep_cnn_model_v1.add(Dropout(0.25))

# 세 번째 컨볼루션 블록
deep_cnn_model_v1.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
deep_cnn_model_v1.add(BatchNormalization())
deep_cnn_model_v1.add(MaxPooling1D(pool_size=2))
deep_cnn_model_v1.add(Dropout(0.25))

# Flatten 및 Dense 레이어
deep_cnn_model_v1.add(Flatten())
deep_cnn_model_v1.add(Dense(128, activation='relu'))
deep_cnn_model_v1.add(Dropout(0.4))

# 출력 레이어
deep_cnn_model_v1.add(Dense(n_outputs, activation='softmax'))

# 모델 컴파일
deep_cnn_model_v1.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

deep_cnn_model_v1.summary()


# ### Cell 4: 훈련 (batch_size=32) ###
print("\n--- 모델 훈련 시작 (batch_size=32) ---")

# 콜백 정의 (EarlyStopping, ReduceLROnPlateau)
early_stopping_cb = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr_cb = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.00001)

# batch_size=32로 훈련
model_history = deep_cnn_model_v1.fit(
    x=X_train, y=y_train_one_hot,
    epochs=50,
    batch_size=32,
    validation_data=(X_val, y_val_one_hot),
    callbacks=[early_stopping_cb, reduce_lr_cb],
    verbose=1
)
print("\n--- 모델 훈련 완료 ---")


# ### Cell 5: 훈련 및 검증 손실 시각화 ###
print("\n--- 훈련/검증 손실 시각화 ---")
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']
epochs_range = range(1, len(loss) + 1)
plt.figure(figsize=(10, 6))
plt.plot(epochs_range, loss, 'y', label='Training loss')
plt.plot(epochs_range, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss (Deeper CNN v1 - Corrected)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()


# ### Cell 6: 훈련 및 검증 정확도 시각화 ###
print("\n--- 훈련/검증 정확도 시각화 ---")
acc = model_history.history['accuracy']
val_acc = model_history.history['val_accuracy']
plt.figure(figsize=(10, 6))
plt.plot(epochs_range, acc, 'y', label='Training acc')
plt.plot(epochs_range, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy (Deeper CNN v1 - Corrected)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()


# ###  Cell 7: 모델 평가 ###
print("\n--- 최종 테스트 데이터 평가 시작 ---")
pred_probs = deep_cnn_model_v1.predict(testX)
pred = np.argmax(pred_probs, axis=-1)

# Confusion Matrix 계산
cm = confusion_matrix(testy, pred)
print("\nConfusion Matrix:")
print(cm)

# Accuracy Score
acc_score = accuracy_score(testy, pred)
print(f"\nAccuracy Score: {acc_score:.4f} (목표: 93% 이상)")

# Classification Report
print("\nClassification Report:")
print(classification_report(testy, pred, digits=3))

# Confusion Matrix 시각화
print("\n--- 혼동 행렬(Confusion Matrix) 시각화 ---")
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=range(6), yticklabels=range(6), cmap='Blues')
plt.title(f'Confusion Matrix (Accuracy: {acc_score:.4f})')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

print("\n--- 모든 과정이 완료되었습니다. ---")
# Out:
# <>:24: SyntaxWarning: invalid escape sequence '\s'
# <>:24: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipython-input-325181420.py:24: SyntaxWarning: invalid escape sequence '\s'
#   dataframe = pd.read_csv(filepath, header=None, sep='\s+')
# --- 데이터 로드 완료 ---
# Train/Test Shapes (X, y, y_one_hot):
# Train: (7352, 128, 9), (7352, 1), (7352, 6)
# Test:  (2947, 128, 9), (2947, 1), (2947, 6)
#
# --- 훈련/검증 데이터 순차 분리 완료 (shuffle=False) ---
#
# --- 변수 설정 완료 ---
# Timesteps: 128, Features: 9, Outputs: 6
#
# --- 1D CNN 모델(v1) 정의 (kernel=3, filters=64,128,128) ---
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_21 (Conv1D)              │ (None, 126, 64)        │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...
