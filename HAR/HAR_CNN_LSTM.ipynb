# %%
import numpy as np
import pandas as pd
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Dense, Flatten, Dropout,
    Conv1D, MaxPooling1D, BatchNormalization,
    LSTM  # LSTM 레이어 사용
)
from tensorflow.keras.callbacks import (
    EarlyStopping, ReduceLROnPlateau
)
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import warnings

# pandas 경고 무시
warnings.filterwarnings('ignore', category=FutureWarning)

# ### Cell 1: 데이터 로드 및 전처리 (Standardization 추가) ###

def load_file(filepath):
    dataframe = pd.read_csv(filepath, header=None, sep='\s+')
    return dataframe.values

def load_group(filenames, prefix=''):
    loaded = list()
    for name in filenames:
        data = load_file(prefix + name)
        loaded.append(data)
    loaded = np.dstack(loaded)
    return loaded

def load_dataset_group(group, prefix=''):
    filepath = prefix + group + '/Inertial Signals/'
    filenames = list()
    filenames += ['total_acc_x_'+group+'.txt', 'total_acc_y_'+group+'.txt', 'total_acc_z_'+group+'.txt']
    filenames += ['body_acc_x_'+group+'.txt', 'body_acc_y_'+group+'.txt', 'body_acc_z_'+group+'.txt']
    filenames += ['body_gyro_x_'+group+'.txt', 'body_gyro_y_'+group+'.txt', 'body_gyro_z_'+group+'.txt']
    X = load_group(filenames, filepath)
    y = load_file(prefix + group + '/y_'+group+'.txt')
    return X, y

def load_dataset(prefix=''):
    # Google Drive 경로
    trainX, trainy = load_dataset_group('train', prefix + '/content/drive/MyDrive/UCI HAR Dataset/')
    testX, testy = load_dataset_group('test', prefix + '/content/drive/MyDrive/UCI HAR Dataset/')

    trainy = trainy - 1
    testy = testy - 1

    trainy_one_hot = to_categorical(trainy)
    testy_one_hot = to_categorical(testy)

    print("--- 데이터 로드 완료 ---")
    return trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot

# --- 데이터 로드 실행 ---
trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot = load_dataset()

# --- 훈련/검증 데이터 순차 분리 (shuffle=False) ---
X_train, X_val, y_train_one_hot, y_val_one_hot, y_train, y_val = train_test_split(
    trainX, trainy_one_hot, trainy, test_size=0.2, random_state=100, shuffle=False
)
print("\n--- 훈련/검증 데이터 순차 분리 완료 (shuffle=False) ---")

# --- 데이터 표준화 (Standardization) ---
mu = X_train.mean(axis=(0,1), keepdims=True)
sigma = X_train.std(axis=(0,1), keepdims=True) + 1e-8
X_train = ((X_train - mu) / sigma).astype('float32')
X_val = ((X_val - mu) / sigma).astype('float32')
testX = ((testX - mu) / sigma).astype('float32')
print("\n--- 데이터 표준화 완료 (Train 통계 기준) ---")


# ### Cell 2: 변수 설정 (이전과 동일) ###
n_timesteps, n_features, n_outputs = X_train.shape[1], X_train.shape[2], y_train_one_hot.shape[1]
print(f"\n--- 변수 설정 완료 ---")
print(f"Timesteps: {n_timesteps}, Features: {n_features}, Outputs: {n_outputs}")


# ### Cell 3 (수정됨): CNN-LSTM (최종 규제 적용) ###
print("\n--- CNN-LSTM 하이브리드 모델 정의 (최종 최적화) ---")

inputs = Input(shape=(n_timesteps, n_features))

# CNN 블록 1
x = Conv1D(filters=128, kernel_size=5, activation='relu', padding='same')(inputs)
x = BatchNormalization()(x)
x = MaxPooling1D(pool_size=2)(x)
x = Dropout(0.3)(x) # 93.55% 모델보다 규제 강화 (0.2 -> 0.3)

# CNN 블록 2
x = Conv1D(filters=64, kernel_size=3, activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling1D(pool_size=2)(x)
x = Dropout(0.3)(x) # 93.55% 모델보다 규제 강화 (0.2 -> 0.3)

# LSTM 블록 (과적합 제어)
x = LSTM(128, recurrent_dropout=0.2)(x) # LSTM 전용 규제 추가
x = Dropout(0.5)(x) # 93.55% 모델과 동일

# Dense 레이어
x = Dense(128, activation='relu')(x)
x = Dropout(0.4)(x) # 과적합 제어를 위한 Dropout 추가 (0.5는 너무 강했음)
outputs = Dense(n_outputs, activation='softmax')(x)

# 모델 생성 및 컴파일
cnn_lstm_model_final = Model(inputs, outputs)
cnn_lstm_model_final.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

cnn_lstm_model_final.summary()


# ### Cell 4: 훈련 (EarlyStopping 기준 = val_accuracy) ###
print("\n--- 모델 훈련 시작 (CNN-LSTM Final) ---")

# EarlyStopping 콜백 (val_accuracy 기준)
early_stopping_cb = EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=10,
    restore_best_weights=True
)

# 학습률 감소 (ReduceLROnPlateau) 콜백
reduce_lr_cb = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.00001)

# batch_size=32로 훈련
model_history = cnn_lstm_model_final.fit(
    x=X_train, y=y_train_one_hot,
    epochs=50,
    batch_size=32,
    validation_data=(X_val, y_val_one_hot),
    callbacks=[early_stopping_cb, reduce_lr_cb],
    verbose=1
)
print("\n--- 모델 훈련 완료 ---")


# ### Cell 5: 훈련 및 검증 손실 시각화 ###
print("\n--- 훈련/검증 손실 시각화 ---")
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']
epochs_range = range(1, len(loss) + 1)
plt.figure(figsize=(10, 6))
plt.plot(epochs_range, loss, 'y', label='Training loss')
plt.plot(epochs_range, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss (CNN-LSTM Final)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()


# ### Cell 6: 훈련 및 검증 정확도 시각화 ###
print("\n--- 훈련/검증 정확도 시각화 ---")
acc = model_history.history['accuracy']
val_acc = model_history.history['val_accuracy']
plt.figure(figsize=(10, 6))
plt.plot(epochs_range, acc, 'y', label='Training acc')
plt.plot(epochs_range, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy (CNN-LSTM Final)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()


# ###  Cell 7: 모델 평가 (오류 수정) ###
print("\n--- 최종 테스트 데이터 평가 시작 ---")
pred_probs = cnn_lstm_model_final.predict(testX)
pred = np.argmax(pred_probs, axis=-1)

# Confusion Matrix 계산
cm = confusion_matrix(testy, pred)
print("\nConfusion Matrix:")
print(cm)

# Accuracy Score
acc_score = accuracy_score(testy, pred)
print(f"\nAccuracy Score: {acc_score:.4f} (목표: 93% 이상)")

# Classification Report
print("\nClassification Report:")
print(classification_report(testy, pred, digits=3))

# Confusion Matrix 시각화
print("\n--- 혼동 행렬(Confusion Matrix) 시각화 ---")
plt.figure(figsize=(10, 8))
# !!! 수정: y_ticklabels -> yticklabels (오타 수정) !!!
sns.heatmap(cm, annot=True, fmt='d', xticklabels=range(6), yticklabels=range(6), cmap='Blues')
plt.title(f'Confusion Matrix (Accuracy: {acc_score:.4f})')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

print("\n--- 모든 과정이 완료되었습니다. ---")
# Out:
# <>:25: SyntaxWarning: invalid escape sequence '\s'
# <>:25: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipython-input-3735802535.py:25: SyntaxWarning: invalid escape sequence '\s'
#   dataframe = pd.read_csv(filepath, header=None, sep='\s+')
# --- 데이터 로드 완료 ---
#
# --- 훈련/검증 데이터 순차 분리 완료 (shuffle=False) ---
#
# --- 데이터 표준화 완료 (Train 통계 기준) ---
#
# --- 변수 설정 완료 ---
# Timesteps: 128, Features: 9, Outputs: 6
#
# --- CNN-LSTM 하이브리드 모델 정의 (최종 최적화) ---
# Model: "functional_132"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_12 (InputLayer)     │ (None, 128, 9)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_32 (Conv1D)              │ (None, 128, 128)       │         5,888 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_32          │ (None, 128, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_32 (MaxPooling1D) │ (None, 64, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_45 (Dropout)            │ (None, 64, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_33 (Conv1D)              │ (None, 64, 64)         │        24,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_33          │ (None, 64, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_33 (MaxPooling1D) │ (None, 32, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_46 (Dropout)            │ (None, 32, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_4 (LSTM)                   │ (None, 128)            │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_47 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_48 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 147,398 (575.77 KB)
#  Trainable params: 147,014 (574.27 KB)
#  Non-trainable params: 384 (1.50 KB)
# --- 모델 훈련 시작 (CNN-LSTM Final) ---
# Epoch 1/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 24s 107ms/step - accuracy: 0.6570 - loss: 0.8497 - val_accuracy: 0.9007 - val_loss: 0.2743 - learning_rate: 0.0010
# Epoch 2/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 21s 110ms/step - accuracy: 0.9361 - loss: 0.1825 - val_accuracy: 0.9164 - val_loss: 0.2424 - learning_rate: 0.0010
# Epoch 3/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 19s 106ms/step - accuracy: 0.9350 - loss: 0.1762 - val_accuracy: 0.9341 - val_loss: 0.1989 - learning_rate: 0.0010
# Epoch 4/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - accuracy: 0.9452 - loss: 0.1371 - val_accuracy: 0.9150 - val_loss: 0.2337 - learning_rate: 0.0010
# Epoch 5/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 19s 105ms/step - accuracy: 0.9477 - loss: 0.1350 - val_accuracy: 0.9184 - val_loss: 0.2856 - learning_rate: 0.0010
# Epoch 6/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - accuracy: 0.9521 - loss: 0.1207 - val_accuracy: 0.9205 - val_loss: 0.2385 - learning_rate: 0.0010
# Epoch 7/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 20s 106ms/step - accuracy: 0.9499 - loss: 0.1145 - val_accuracy: 0.9354 - val_loss: 0.2727 - learning_rate: 0.0010
# Epoch 8/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 21s 111ms/step - accuracy: 0.9538 - loss: 0.1053 - val_accuracy: 0.9327 - val_loss: 0.2485 - learning_rate: 0.0010
# Epoch 9/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 19s 105ms/step - accuracy: 0.9583 - loss: 0.0958 - val_accuracy: 0.9327 - val_loss: 0.2578 - learning_rate: 5.0000e-04
# Epoch 10/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 21s 106ms/step - accuracy: 0.9542 - loss: 0.1005 - val_accuracy: 0.9225 - val_loss: 0.2611 - learning_rate: 5.0000e-04
# Epoch 11/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 21s 114ms/step - accuracy: 0.9574 - loss: 0.0899 - val_accuracy: 0.9327 - val_loss: 0.2759 - learning_rate: 5.0000e-04
# Epoch 12/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 19s 105ms/step - accuracy: 0.9596 - loss: 0.0841 - val_accuracy: 0.9232 - val_loss: 0.2717 - learning_rate: 5.0000e-04
# Epoch 13/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 20s 110ms/step - accuracy: 0.9576 - loss: 0.0957 - val_accuracy: 0.9313 - val_loss: 0.2851 - learning_rate: 5.0000e-04
# Epoch 14/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 19s 105ms/step - accuracy: 0.9605 - loss: 0.0942 - val_accuracy: 0.9232 - val_loss: 0.2736 - learning_rate: 2.5000e-04
# Epoch 15/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - accuracy: 0.9650 - loss: 0.0766 - val_accuracy: 0.9211 - val_loss: 0.3399 - learning_rate: 2.5000e-04
# Epoch 16/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 19s 105ms/step - accuracy: 0.9551 - loss: 0.0877 - val_accuracy: 0.9307 - val_loss: 0.3407 - learning_rate: 2.5000e-04
# Epoch 17/50
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - accuracy: 0.9581 - loss: 0.0854 - val_accuracy: 0.9239 - val_loss: 0.2941 - learning_rate: 2.5000e-04
#
# --- 모델 훈련 완료 ---
#
# --- 훈련/검증 손실 시각화 ---
# --- 훈련/검증 정확도 시각화 ---
# --- 최종 테스트 데이터 평가 시작 ---
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step
#
# Confusion Matrix:
# [[494   0   2   0   0   0]
#  [ 11 453   7   0   0   0]
#  [  0   0 420   0   0   0]
#  [  0   9   0 417  65   0]
#  [  0   0   0 112 420   0]
#  [  0   0   0   0   0 537]]
#
# Accuracy Score: 0.9301 (목표: 93% 이상)
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0      0.978     0.996     0.987       496
#            1      0.981     0.962     0.971       471
#            2      0.979     1.000     0.989       420
#            3      0.788     0.849     0.818       491
#            4      0.866     0.789     0.826       532
#            5      1.000     1.000     1.000       537
#
#     accuracy                          0.930      2947
#    macro avg      0.932     0.933     0.932      2947
# weighted avg      0.931     0.930     0.930      2947
#
#
# --- 혼동 행렬(Confusion Matrix) 시각화 ---
# --- 모든 과정이 완료되었습니다. ---
